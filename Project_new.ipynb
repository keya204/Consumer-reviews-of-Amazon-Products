# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msgno
from wordcloud import WordCloud, STOPWORDS
import string
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score, cross_validate
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Loading the Dataset

# %%
df= pd.read_csv("1429_1.csv")
df.head()
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# 0  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 1  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 2  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 3  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 4  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
#
#                reviews.date     reviews.dateAdded  \
# 0  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 1  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 2  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 3  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 4  2017-01-12T00:00:00.000Z  2017-07-03T23:33:15Z
#
#                                     reviews.dateSeen  ... reviews.doRecommend  \
# 0  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
# 1  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
# 2  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
# 3  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
# 4  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
#
#   reviews.id  reviews.numHelpful  reviews.rating  \
# 0        NaN                 0.0             5.0
# 1        NaN                 0.0             5.0
# 2        NaN                 0.0             5.0
# 3        NaN                 0.0             4.0
# 4        NaN                 0.0             5.0
#
#                                   reviews.sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/5620406/review...
# 1  http://reviews.bestbuy.com/3545/5620406/review...
# 2  http://reviews.bestbuy.com/3545/5620406/review...
# 3  http://reviews.bestbuy.com/3545/5620406/review...
# 4  http://reviews.bestbuy.com/3545/5620406/review...
#
#                                         reviews.text  \
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
# 3  I've had my Fire HD 8 two weeks now and I love...
# 4  I bought this for my grand daughter when she c...
#
#                              reviews.title reviews.userCity  \
# 0                                   Kindle              NaN
# 1                                very fast              NaN
# 2  Beginner tablet for our 9 year old son.              NaN
# 3                                  Good!!!              NaN
# 4                Fantastic Tablet for kids              NaN
#
#    reviews.userProvince  reviews.username
# 0                   NaN           Adapter
# 1                   NaN            truman
# 2                   NaN             DaveZ
# 3                   NaN            Shacks
# 4                   NaN         explore42
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (34660, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34660 entries, 0 to 34659
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    34660 non-null  object
#  1   name                  27900 non-null  object
#  2   asins                 34658 non-null  object
#  3   brand                 34660 non-null  object
#  4   categories            34660 non-null  object
#  5   keys                  34660 non-null  object
#  6   manufacturer          34660 non-null  object
#  7   reviews.date          34621 non-null  object
#  8   reviews.dateAdded     24039 non-null  object
#  9   reviews.dateSeen      34660 non-null  object
#  10  reviews.didPurchase   1 non-null      object
#  11  reviews.doRecommend   34066 non-null  object
#  12  reviews.id            1 non-null      float64
#  13  reviews.numHelpful    34131 non-null  float64
#  14  reviews.rating        34627 non-null  float64
#  15  reviews.sourceURLs    34660 non-null  object
#  16  reviews.text          34659 non-null  object
#  17  reviews.title         34655 non-null  object
#  18  reviews.userCity      0 non-null      float64
#  19  reviews.userProvince  0 non-null      float64
#  20  reviews.username      34658 non-null  object
# dtypes: float64(5), object(16)
# memory usage: 5.6+ MB

# %%
df.describe()
# Out:
#         reviews.id  reviews.numHelpful  reviews.rating  reviews.userCity  \
# count          1.0        34131.000000    34627.000000               0.0
# mean   111372787.0            0.630248        4.584573               NaN
# std            NaN           13.215775        0.735653               NaN
# min    111372787.0            0.000000        1.000000               NaN
# 25%    111372787.0            0.000000        4.000000               NaN
# 50%    111372787.0            0.000000        5.000000               NaN
# 75%    111372787.0            0.000000        5.000000               NaN
# max    111372787.0          814.000000        5.000000               NaN
#
#        reviews.userProvince
# count                   0.0
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %% [markdown]
# ### Checking if the columns are continuous or categorical

# %%
Continuous_features = [feature for feature in df.columns if len(df[feature].unique())>10]
print('Continuous attributes are : {}'.format(Continuous_features))

Categorial_features = [feature for feature in df.columns if len(df[feature].unique())<10]
print('Categorial attributes are : {}'.format(Categorial_features))
# Out:
# Continuous attributes are : ['id', 'name', 'asins', 'categories', 'keys', 'reviews.date', 'reviews.dateAdded', 'reviews.dateSeen', 'reviews.numHelpful', 'reviews.sourceURLs', 'reviews.text', 'reviews.title', 'reviews.username']
# Categorial attributes are : ['brand', 'manufacturer', 'reviews.didPurchase', 'reviews.doRecommend', 'reviews.id', 'reviews.rating', 'reviews.userCity', 'reviews.userProvince']

# %% [markdown]
# ### Checking the null values in each column

# %%
df.isnull().sum()
# Out:
# id                          0
# name                     6760
# asins                       2
# brand                       0
# categories                  0
# keys                        0
# manufacturer                0
# reviews.date               39
# reviews.dateAdded       10621
# reviews.dateSeen            0
# reviews.didPurchase     34659
# reviews.doRecommend       594
# reviews.id              34659
# reviews.numHelpful        529
# reviews.rating             33
# reviews.sourceURLs          0
# reviews.text                1
# reviews.title               5
# reviews.userCity        34660
# reviews.userProvince    34660
# reviews.username            2
# dtype: int64

# %%
def missing(df):
    msgno.matrix(df)
    plt.show()
missing(df)

# %%
print(df.isna().mean().round(4) * 100)
# Out:
# id                        0.00
# name                     19.50
# asins                     0.01
# brand                     0.00
# categories                0.00
# keys                      0.00
# manufacturer              0.00
# reviews.date              0.11
# reviews.dateAdded        30.64
# reviews.dateSeen          0.00
# reviews.didPurchase     100.00
# reviews.doRecommend       1.71
# reviews.id              100.00
# reviews.numHelpful        1.53
# reviews.rating            0.10
# reviews.sourceURLs        0.00
# reviews.text              0.00
# reviews.title             0.01
# reviews.userCity        100.00
# reviews.userProvince    100.00
# reviews.username          0.01
# dtype: float64

# %% [markdown]
# Here we can see that there are no values in reviews.didPurchase, reviews.id, reviews.userCity, reviews.userProvince columns of the dataset, so its better to remove it.

# %%
df.drop(['reviews.didPurchase', 'reviews.id', 'reviews.userCity','reviews.userProvince', 'reviews.dateAdded'], axis=1, inplace=True)

# %% [markdown]
# Since we have large dataset we can eliminate the null values.

# %%
df.dropna(inplace=True)

# %%
def countplot(x1,df,title):
    sns.set_style("dark")
    sns.countplot(x=x1, data=df, palette=sns.color_palette("Paired", 7), saturation=10)
    plt.title(title,fontsize = 20)
    plt.show()

# %%
countplot('reviews.rating', df ,'No of Users' )
countplot('brand', df ,'No of brands' )

# %%
countplot('reviews.doRecommend',df,'recommend: yes or no')

# %% [markdown]
# ### Sentiment Analysis

# %%
def convert_ratings(x):
    if x < 4:
        return 0
    if x >= 4:
        return 1
vect_func = np.vectorize(convert_ratings)
df['sentiments'] = df['reviews.rating'].map(vect_func)

# %% [markdown]
# ### Checking if new sentiments column is added to the dataset where all the ratings that were less 4 are 0 and greater than 4 are allocated 1

# %%
df[df['reviews.rating']<4]
# Out:
#                          id  \
# 117    AVqkIhwDv8e3D1O-lebb
# 126    AVqkIhwDv8e3D1O-lebb
# 169    AVqkIhwDv8e3D1O-lebb
# 222    AVqkIhwDv8e3D1O-lebb
# 226    AVqkIhwDv8e3D1O-lebb
# ...                     ...
# 27865  AVpfl8cLLJeJML43AE3S
# 27877  AVpfl8cLLJeJML43AE3S
# 27891  AVpfl8cLLJeJML43AE3S
# 27894  AVpfl8cLLJeJML43AE3S
# 27898  AVpfl8cLLJeJML43AE3S
#
#                                                     name  \
# 117    All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 126    All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 169    All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 222    All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 226    All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# ...                                                  ...
# 27865             Amazon Fire Tv,,,\r\nAmazon Fire Tv,,,
# 27877             Amazon Fire Tv,,,\r\nAmazon Fire Tv,,,
# 27891  Amazon Kindle Fire 5ft USB to Micro-USB Cable ...
# 27894  New Amazon Kindle Fire Hd 9w Powerfast Adapter...
# 27898  New Amazon Kindle Fire Hd 9w Powerfast Adapter...
#
#                        asins   brand  \
# 117               B01AHB9CN2  Amazon
# 126               B01AHB9CN2  Amazon
# 169               B01AHB9CN2  Amazon
# 222               B01AHB9CN2  Amazon
# 226               B01AHB9CN2  Amazon
# ...                      ...     ...
# 27865  B00L9EPT8O,B01E6AO69U  Amazon
# 27877  B00L9EPT8O,B01E6AO69U  Amazon
# 27891  B00L9EPT8O,B01E6AO69U  Amazon
# 27894  B00L9EPT8O,B01E6AO69U  Amazon
# 27898  B00L9EPT8O,B01E6AO69U  Amazon
#
#                                               categories  \
# 117    Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 126    Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 169    Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 222    Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 226    Electronics,iPad & Tablets,All Tablets,Fire Ta...
# ...                                                  ...
# 27865  Stereos,Remote Controls,Amazon Echo,Audio Dock...
# 27877  Stereos,Remote Controls,Amazon Echo,Audio Dock...
# 27891  Stereos,Remote Controls,Amazon Echo,Audio Dock...
# 27894  Stereos,Remote Controls,Amazon Echo,Audio Dock...
# 27898  Stereos,Remote Controls,Amazon Echo,Audio Dock...
#
#                                                     keys manufacturer  \
# 117    841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 126    841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 169    841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 222    841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 226    841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# ...                                                  ...          ...
# 27865  echowhite/263039693056,echowhite/152558276095,...       Amazon
# 27877  echowhite/263039693056,echowhite/152558276095,...       Amazon
# 27891  echowhite/263039693056,echowhite/152558276095,...       Amazon
# 27894  echowhite/263039693056,echowhite/152558276095,...       Amazon
# 27898  echowhite/263039693056,echowhite/152558276095,...       Amazon
#
#                    reviews.date  \
# 117    2017-01-08T00:00:00.000Z
# 126    2017-01-10T00:00:00.000Z
# 169    2016-11-25T00:00:00.000Z
# 222    2016-12-30T00:00:00.000Z
# 226    2017-01-03T00:00:00.000Z
# ...                         ...
# 27865  2016-08-02T00:00:00.000Z
# 27877  2016-07-23T00:00:00.000Z
# 27891  2016-08-12T00:00:00.000Z
# 27894  2016-08-17T00:00:00.000Z
# 27898  2016-08-14T00:00:00.000Z
#
#                                         reviews.dateSeen reviews.doRecommend  \
# 117    2017-04-30T00:45:00.000Z,2017-06-07T09:03:00.000Z                True
# 126    2017-04-30T00:45:00.000Z,2017-06-07T09:03:00.000Z               False
# 169    2017-04-30T00:44:00.000Z,2017-06-07T09:00:00.000Z               False
# 222    2017-04-30T00:43:00.000Z,2017-06-07T09:03:00.000Z               False
# 226    2017-04-30T00:43:00.000Z,2017-06-07T09:03:00.000Z               False
# ...                                                  ...                 ...
# 27865  2017-09-28T00:00:00Z,2017-09-08T00:00:00Z,2017...                True
# 27877  2017-09-28T00:00:00Z,2017-09-08T00:00:00Z,2017...               False
# 27891  2017-09-28T00:00:00Z,2017-09-08T00:00:00Z,2017...                True
# 27894  2017-09-28T00:00:00Z,2017-09-08T00:00:00Z,2017...               False
# 27898  2017-09-28T00:00:00Z,2017-09-08T00:00:00Z,2017...               False
#
#        reviews.numHelpful  reviews.rating  \
# 117                   0.0             2.0
# 126                   2.0             1.0
# 169                   2.0             1.0
# 222                   0.0             3.0
# 226                   0.0             3.0
# ...                   ...             ...
# 27865                 0.0             3.0
# 27877                 0.0             3.0
# 27891                 0.0             3.0
# 27894                 0.0             3.0
# 27898                 0.0             3.0
#
#                                       reviews.sourceURLs  \
# 117    http://reviews.bestbuy.com/3545/5620406/review...
# 126    http://reviews.bestbuy.com/3545/5620406/review...
# 169    http://reviews.bestbuy.com/3545/5620406/review...
# 222    http://reviews.bestbuy.com/3545/5620406/review...
# 226    http://reviews.bestbuy.com/3545/5620406/review...
# ...                                                  ...
# 27865  http://reviews.bestbuy.com/3545/5588528/review...
# 27877  http://reviews.bestbuy.com/3545/5588528/review...
# 27891  http://reviews.bestbuy.com/3545/5588528/review...
# 27894  http://reviews.bestbuy.com/3545/5588528/review...
# 27898  http://reviews.bestbuy.com/3545/5588528/review...
#
#                                             reviews.text  \
# 117    Didn't have some of the features I was looking...
# 126    i Bought this around black friday for $60 hopi...
# 169    I bought this tablet for my 4 year old daughte...
# 222    I was hoping to use Google launcher with this ...
# 226    The tablet works fine. It is responsive with g...
# ...                                                  ...
# 27865  Alexa can do basic things, hard to find tune s...
# 27877  This is a neat product but did not fit my need...
# 27891  Good speaker but limited if you don't have a b...
# 27894  So I was excited to get this when Best Buy sta...
# 27898  This is great for a connected home. People who...
#
#                             reviews.title reviews.username  sentiments
# 117                         Wasn't for me             Mark           0
# 126                     TERRIBLE DONT BUY          Brandon           0
# 169                    Ended up returning           Mijenx           0
# 222                        A cheap tablet         blargh22           0
# 226    Works well but too tied to Amazon.            AZ23b           0
# ...                                   ...              ...         ...
# 27865                      Learning curve   SqueakingTiger           0
# 27877                                  Ok             Greg           0
# 27891                        Good speaker    dysfunctional           0
# 27894                  Great buy lacking.             nb99           0
# 27898        Great for a "connected home"       Litopine18           0
#
# [1887 rows x 17 columns]

# %%
df[df['reviews.rating']>=4]
# Out:
#                          id  \
# 0      AVqkIhwDv8e3D1O-lebb
# 1      AVqkIhwDv8e3D1O-lebb
# 2      AVqkIhwDv8e3D1O-lebb
# 3      AVqkIhwDv8e3D1O-lebb
# 4      AVqkIhwDv8e3D1O-lebb
# ...                     ...
# 27893  AVpfl8cLLJeJML43AE3S
# 27895  AVpfl8cLLJeJML43AE3S
# 27896  AVpfl8cLLJeJML43AE3S
# 27897  AVpfl8cLLJeJML43AE3S
# 27899  AVpfl8cLLJeJML43AE3S
#
#                                                     name  \
# 0      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# ...                                                  ...
# 27893  New Amazon Kindle Fire Hd 9w Powerfast Adapter...
# 27895  New Amazon Kindle Fire Hd 9w Powerfast Adapter...
# 27896  New Amazon Kindle Fire Hd 9w Powerfast Adapter...
# 27897  New Amazon Kindle Fire Hd 9w Powerfast Adapter...
# 27899  New Amazon Kindle Fire Hd 9w Powerfast Adapter...
#
#                        asins   brand  \
# 0                 B01AHB9CN2  Amazon
# 1                 B01AHB9CN2  Amazon
# 2                 B01AHB9CN2  Amazon
# 3                 B01AHB9CN2  Amazon
# 4                 B01AHB9CN2  Amazon
# ...                      ...     ...
# 27893  B00L9EPT8O,B01E6AO69U  Amazon
# 27895  B00L9EPT8O,B01E6AO69U  Amazon
# 27896  B00L9EPT8O,B01E6AO69U  Amazon
# 27897  B00L9EPT8O,B01E6AO69U  Amazon
# 27899  B00L9EPT8O,B01E6AO69U  Amazon
#
#                                               categories  \
# 0      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# ...                                                  ...
# 27893  Stereos,Remote Controls,Amazon Echo,Audio Dock...
# 27895  Stereos,Remote Controls,Amazon Echo,Audio Dock...
# 27896  Stereos,Remote Controls,Amazon Echo,Audio Dock...
# 27897  Stereos,Remote Controls,Amazon Echo,Audio Dock...
# 27899  Stereos,Remote Controls,Amazon Echo,Audio Dock...
#
#                                                     keys manufacturer  \
# 0      841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 1      841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 2      841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 3      841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 4      841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# ...                                                  ...          ...
# 27893  echowhite/263039693056,echowhite/152558276095,...       Amazon
# 27895  echowhite/263039693056,echowhite/152558276095,...       Amazon
# 27896  echowhite/263039693056,echowhite/152558276095,...       Amazon
# 27897  echowhite/263039693056,echowhite/152558276095,...       Amazon
# 27899  echowhite/263039693056,echowhite/152558276095,...       Amazon
#
#                    reviews.date  \
# 0      2017-01-13T00:00:00.000Z
# 1      2017-01-13T00:00:00.000Z
# 2      2017-01-13T00:00:00.000Z
# 3      2017-01-13T00:00:00.000Z
# 4      2017-01-12T00:00:00.000Z
# ...                         ...
# 27893  2016-08-12T00:00:00.000Z
# 27895  2016-08-16T00:00:00.000Z
# 27896  2016-08-16T00:00:00.000Z
# 27897  2016-08-15T00:00:00.000Z
# 27899  2016-08-14T00:00:00.000Z
#
#                                         reviews.dateSeen reviews.doRecommend  \
# 0      2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z                True
# 1      2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z                True
# 2      2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z                True
# 3      2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z                True
# 4      2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z                True
# ...                                                  ...                 ...
# 27893  2017-09-28T00:00:00Z,2017-09-08T00:00:00Z,2017...                True
# 27895  2017-09-28T00:00:00Z,2017-09-08T00:00:00Z,2017...                True
# 27896  2017-09-28T00:00:00Z,2017-09-08T00:00:00Z,2017...                True
# 27897  2017-09-28T00:00:00Z,2017-09-08T00:00:00Z,2017...                True
# 27899  2017-09-28T00:00:00Z,2017-09-08T00:00:00Z,2017...                True
#
#        reviews.numHelpful  reviews.rating  \
# 0                     0.0             5.0
# 1                     0.0             5.0
# 2                     0.0             5.0
# 3                     0.0             4.0
# 4                     0.0             5.0
# ...                   ...             ...
# 27893                 0.0             5.0
# 27895                 0.0             5.0
# 27896                 0.0             5.0
# 27897                 6.0             4.0
# 27899                 0.0             5.0
#
#                                       reviews.sourceURLs  \
# 0      http://reviews.bestbuy.com/3545/5620406/review...
# 1      http://reviews.bestbuy.com/3545/5620406/review...
# 2      http://reviews.bestbuy.com/3545/5620406/review...
# 3      http://reviews.bestbuy.com/3545/5620406/review...
# 4      http://reviews.bestbuy.com/3545/5620406/review...
# ...                                                  ...
# 27893  http://reviews.bestbuy.com/3545/5588528/review...
# 27895  http://reviews.bestbuy.com/3545/5588528/review...
# 27896  http://reviews.bestbuy.com/3545/5588528/review...
# 27897  http://reviews.bestbuy.com/3545/5588528/review...
# 27899  http://reviews.bestbuy.com/3545/5588528/review...
#
#                                             reviews.text  \
# 0      This product so far has not disappointed. My c...
# 1      great for beginner or experienced person. Boug...
# 2      Inexpensive tablet for him to use and learn on...
# 3      I've had my Fire HD 8 two weeks now and I love...
# 4      I bought this for my grand daughter when she c...
# ...                                                  ...
# 27893  Just love it. Easy to set up and use. Tons of ...
# 27895  This is my new favorite device. While not perf...
# 27896  I got this to basically experiment with. Strai...
# 27897  Good product that does the basics. Too bad you...
# 27899  Cool product. Amazon does a cool job with it. ...
#
#                                  reviews.title          reviews.username  \
# 0                                       Kindle                   Adapter
# 1                                    very fast                    truman
# 2      Beginner tablet for our 9 year old son.                     DaveZ
# 3                                      Good!!!                    Shacks
# 4                    Fantastic Tablet for kids                 explore42
# ...                                        ...                       ...
# 27893                             My new robot               imabull2014
# 27895                  My new favorite product                  JefferyP
# 27896                     Lots of potential!!!                shelbydave
# 27897            Good First Generation Product  Tiredofchoosingnicknames
# 27899                                 Cool toy        TheHUnTer525batman
#
#        sentiments
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 27893           1
# 27895           1
# 27896           1
# 27897           1
# 27899           1
#
# [25519 rows x 17 columns]

# %%
df.drop(df['reviews.rating'], inplace=True)

# %%
df.sentiments.hist();

# %%
plt.figure(figsize= (10,10))
label=['1','0']
plt.pie(df['sentiments'].value_counts(), autopct='%0.2f%%')
plt.legend(label)
plt.title('Sentiments Distribution')
# Out:
# Text(0.5, 1.0, 'Sentiments Distribution')

# %% [markdown]
# Now for Reviews.text column we need to check which words are used the maximum time.

# %%
plt.figure(figsize=(10,12))
words_count = pd.Series((df['reviews.text']))
wordcloud = WordCloud(width=1000, height=1000).generate(' '.join(words_count))

plt.imshow(wordcloud)
plt.show()

# %%
#stop words are those words which are very basic & wont be of any for our prediction 
stopwords = set(STOPWORDS)
stop_words=list(stopwords)
print(stopwords)
# Out:
# {"wouldn't", 'its', 'my', 'once', "she's", 'as', "hadn't", 'them', "shouldn't", 'by', 'was', 'did', 'against', 'had', "i'd", "that's", 'which', 'having', 'both', "who's", "won't", 'below', "she'd", "let's", 'herself', 'otherwise', 'nor', "i'm", 'you', 'whom', 'for', 'such', "couldn't", 'hence', 'if', 'under', 'here', 'she', "you'll", 'however', "shan't", 'ours', 'this', "when's", 'yours', 'r', 'that', 'hers', 'how', 'i', 'are', 'like', 'off', 'ought', "there's", 'we', 'would', 'on', 'over', 'with', "he'd", 'after', 'be', 'yourself', 'themselves', 'than', "we'd", "she'll", "where's", 'does', "don't", 'above', 'and', 'do', 'further', 'am', 'again', "weren't", 'myself', 'have', 'few', 'between', 'of', 'in', 'very', 'should', "he's", 'during', 'before', 'so', 'most', "what's", 'but', 'cannot', "how's", 'then', 'more', 'who', 'get', 'our', 'into', 'an', 'those', 'any', "i've", 'has', 'theirs', 'were', 'www', 'about', 'is', 'it', "aren't", 'too', 'been', "they'll", 'where', 'all', 'could', "doesn't", 'her', 'they', 'just', "isn't", 'their', 'or', "you'd", 'through', 'since', "you're", 'he', 'doing', 'not', 'out', 'the', 'because', "i'll", 'me', 'can', 'from', 'no', 'when', 'while', "you've", "didn't", 'being', 'down', 'com', 'until', "we're", 'a', 'shall', "can't", "here's", 'up', 'only', 'each', 'http', 'him', 'yourselves', 'ever', 'same', "it's", 'himself', "they'd", 'therefore', 'also', 'other', "they've", 'why', 'k', "we've", "why's", 'there', 'own', "hasn't", 'these', "wasn't", "he'll", 'his', 'what', 'ourselves', 'itself', 'some', 'to', "we'll", "mustn't", 'your', "they're", "haven't", 'else', 'at'}

# %%
import string
from nltk.corpus import stopwords
def text_process(text):
    nopunc = [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

def filtertext(df):
    filtertext = []
    for i in df['reviews.text']:
        df_new = text_process(i)
        mystring = ' '.join([str(item) for item in df_new])
        filtertext.append(mystring)
    return filtertext

# %%
df_copy= pd.DataFrame({'reviews_filtertext': filtertext(df)})
df['reviews_text']= filtertext(df)

# %%
df['reviews_text']
# Out:
# 0        product far disappointed children love use lik...
# 6        Great ereading go nice light weight price poin...
# 7        gave Christmas gift inlaws husband uncle loved...
# 8        Great device read books like links borrowed li...
# 9                       love ordering books reading reader
#                                ...
# 27895    new favorite device perfect lot un useOne feat...
# 27896    got basically experiment Straight box really i...
# 27897    Good product basics bad buy specific light con...
# 27898    great connected home People use buy plan makin...
# 27899    Cool product Amazon cool job Great audio quali...
# Name: reviews_text, Length: 27401, dtype: object

# %% [markdown]
# ### Count Vectorization

# %%
vectorizer = CountVectorizer(max_features=800)
vectorizer.fit(df['reviews_text'])
features= vectorizer.transform(df['reviews_text'])
features.toarray()

cv_idf = pd.DataFrame(features.toarray(), columns=vectorizer.get_feature_names())
X_train, X_test, y_train, y_test = train_test_split(cv_idf, df['sentiments'], test_size=0.4, random_state=42)

# %% [markdown]
# ### XGBoost

# %%
xgb = XGBClassifier()
cv_results = cross_validate(xgb, X_train, y_train, cv=5)
print(cv_results['test_score'].mean())
xgb.fit(X_train, y_train)
result = xgb.predict(X_test)
accuracy = accuracy_score(y_test,result)
print(accuracy)
# Out:
# [16:08:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:08:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:08:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:08:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:08:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9363138686131386
# [16:08:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9382355624486817

# %% [markdown]
# ### XGBoost with Hyperparameter

# %%
xgb_h = XGBClassifier(learning_rate =0.01,n_estimators=800,max_depth=9,min_child_weight=1,gamma=0,subsample=0.8,
        colsample_bytree=0.8,objective= 'binary:logistic',nthread=4,scale_pos_weight=1,seed=27)
cv_results_h = cross_validate(xgb_h, X_train, y_train, cv=5)
print(cv_results_h['test_score'].mean())
xgb_h.fit(X_train, y_train)
result_xgb_h = xgb_h.predict(X_test)
accuracy = accuracy_score(y_test,result)
print(accuracy)
# Out:
# [16:41:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:43:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:44:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:46:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:47:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9356447688564478
# [16:49:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9382355624486817

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
cv_results_logreg = cross_validate(logreg, X_train, y_train, cv=10,scoring='accuracy')
print(cv_results_logreg['test_score'].mean())
logreg.fit(X_train, y_train)
logreg_predictions = logreg.predict(X_test)
# Out:
# 0.9357055961070561

# %% [markdown]
# ### KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier(n_neighbors = 4)
cv_results_knn = cross_validate(model_knn, X_train, y_train, cv=5)
print(cv_results_knn['test_score'].mean())
model_knn.fit(X_train, y_train)
model_knn = model_knn.predict(X_test)
# Out:
# 0.9263381995133819

# %% [markdown]
# ### AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
model_ada= AdaBoostClassifier()
cv_results_ada = cross_validate(model_ada, X_train, y_train, cv=5)
print(cv_results_ada['test_score'].mean())
model_ada.fit(X_train, y_train)
model_ada = model_ada.predict(X_test)
# Out:
# 0.9332116788321168

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model_gnb= GaussianNB()
cv_results_gnb = cross_validate(model_gnb, X_train, y_train, cv=6)
print(cv_results_gnb['test_score'].mean())
model_gnb.fit(X_train, y_train)
model_gnb = model_gnb.predict(X_test)
# Out:
# 0.41204379562043797

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
model_dtc= DecisionTreeClassifier(criterion='gini', 
                             min_samples_split=10,min_samples_leaf=1,
                             max_features='auto')
cv_results_dectree = cross_validate(model_dtc, X_train, y_train, cv=5)
print(cv_results_dectree['test_score'].mean())
model_dtc.fit(X_train, y_train)
model_dtc = model_dtc.predict(X_test)
# Out:
# 0.9098540145985401

# %% [markdown]
# ### Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
cv_results_rf = cross_validate(rf, X_train, y_train, cv=5)
print(cv_results_rf['test_score'].mean())
rf.fit(X_train, y_train)
rf = rf.predict(X_test)
# Out:
# 0.9331508515815085

# %% [markdown]
# ### TF_IDF Vectorization

# %%
vectorizer_tf = TfidfVectorizer()
vectorizer_tf.fit(df['reviews_text'])
features= vectorizer_tf.transform(df['reviews_text'])
features.toarray()

tf_idf = pd.DataFrame(features.toarray(), columns=vectorizer_tf.get_feature_names())
X_train, X_test, y_train, y_test = train_test_split(tf_idf, df['sentiments'], test_size=0.2, random_state=42)

# %% [markdown]
# ### Logistic Regression

# %%
logreg_tf = LogisticRegression()
results_logreg_tf = cross_validate(logreg_tf, X_train, y_train,scoring='accuracy')
print(results_logreg_tf['test_score'].mean())
logreg_tf.fit(X_train, y_train)
logreg_tf_predictions = logreg_tf.predict(X_test)
# Out:
# 0.9366332116788321

# %% [markdown]
# ### XGBoost

# %%
xgb_tf = XGBClassifier()
results_tf = cross_validate(xgb, X_train, y_train)
print(results_tf['test_score'].mean())
xgb_tf.fit(X_train, y_train)
result = xgb_tf.predict(X_test)
accuracy = accuracy_score(y_test,result)
print(accuracy)
# Out:
# [20:27:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:09:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:12:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:15:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:18:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9381843065693429
# [21:21:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9341361065498996

# %% [markdown]
# ### AdaBoost Algorithm

# %%
from sklearn.ensemble import AdaBoostClassifier
model_ada_tf= AdaBoostClassifier()
results_ada_tf = cross_validate(model_ada, X_train, y_train, cv=5)
print(results_ada_tf['test_score'].mean())
model_ada_tf.fit(X_train, y_train)
model_ada_tf = model_ada_tf.predict(X_test)
# Out:
# 0.9336678832116787
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-db67bd0aadbb> in <module>
#       3 results_ada_tf = cross_validate(model_ada, X_train, y_train, cv=5)
#       4 print(results_ada_tf['test_score'].mean())
# ----> 5 model_ada_tf.fit(X_train, y_train)
#       6 model_ada_tf = model_ada_tf.predict(X_test)
#
# D:\Anaconda\lib\site-packages\sklearn\ensemble\_weight_boosting.py in fit(self, X, y, sample_weight)
#     441
#     442         # Fit
# --> 443         return super().fit(X, y, sample_weight)
#     444
#     445     def _validate_estimator(self):
#
# D:\Anaconda\lib\site-packages\sklearn\ensemble\_weight_boosting.py in fit(self, X, y, sample_weight)
#     128         for iboost in range(self.n_estimators):
#     129             # Boosting step
# --> 130             sample_weight, estimator_weight, estimator_error = self._boost(
#     131                 iboost,
#     132                 X, y,
#
# D:\Anaconda\lib\site-packages\sklearn\ensemble\_weight_boosting.py in _boost(self, iboost, X, y, sample_weight, random_state)
#     501         """
#     502         if self.algorithm == 'SAMME.R':
# --> 503             return self._boost_real(iboost, X, y, sample_weight, random_state)
#     504
#     505         else:  # elif self.algorithm == "SAMME":
#
# D:\Anaconda\lib\site-packages\sklearn\ensemble\_weight_boosting.py in _boost_real(self, iboost, X, y, sample_weight, random_state)
#     511         estimator = self._make_estimator(random_state=random_state)
#     512
# --> 513         estimator.fit(X, y, sample_weight=sample_weight)
#     514
#     515         y_predict_proba = estimator.predict_proba(X)
#
# D:\Anaconda\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# D:\Anaconda\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
model_dtc_tf= DecisionTreeClassifier(criterion='gini', 
                             min_samples_split=10,min_samples_leaf=1,
                             max_features='auto')
results_dectree_tf = cross_validate(model_dtc_tf, X_train, y_train)
model_dtc_tf.fit(X_train, y_train)
model_dtc_tf = model_dtc_tf.predict(X_test)
# Out:
# 0.9098540145985401

# %%
models = pd.DataFrame({
    'Model': ['XgBoost', 'XGboost with hyperparameter tuning', 'Logistic Regression', 
              'KNN classification', 'ADA Classifier', 'Gaussian Naive Bayes', 'Decision Tree classifier', 'Random forest algorithm'],
    'Score': [cv_results['test_score'].mean(),cv_results_h['test_score'].mean(),cv_results_logreg['test_score'].mean(),
             cv_results_knn['test_score'].mean(), cv_results_ada['test_score'].mean(),cv_results_gnb['test_score'].mean(),
             cv_results_dectree['test_score'].mean(),cv_results_rf['test_score'].mean()]})
models
# Out:
#                                 Model     Score
# 0                             XgBoost  0.933516
# 1  XGboost with hyperparameter tuning  0.935645
# 2                 Logistic Regression  0.935706
# 3                  KNN classification  0.926338
# 4                      ADA Classifier  0.933212
# 5                Gaussian Naive Bayes  0.412044
# 6            Decision Tree classifier  0.909854
# 7             Random forest algorithm  0.933151

# %%
models_tf = pd.DataFrame({
    'Model': ['XgBoost', 'Logistic Regression', 
               'ADA Classifier', 'Decision Tree classifier'],
    'Score': [results_tf['test_score'].mean(),results_logreg_tf['test_score'].mean(),   
              results_ada_tf['test_score'].mean(),results_dectree_tf['test_score'].mean()
                         ]})
models_tf
# Out:
#                       Model     Score
# 0                   XgBoost  0.938184
# 1       Logistic Regression  0.936633
# 2            ADA Classifier  0.933668
# 3  Decision Tree classifier  0.904562
